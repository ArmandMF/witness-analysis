# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Base/WIP_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c1 = pd.read_excel('SC1/WIP_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c2 = pd.read_excel('SC2/WIP_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c3 = pd.read_excel('SC3/WIP_ASIS_B1000.xlsx', sheet_name='Sheet1')

data_lt = pd.read_excel('Base/WIP_ASIS_B1000_lt.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_500 = pd.read_excel('Base/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_500_lt = pd.read_excel('Base/WIP_ASIS_B500_lt.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_50 = pd.read_excel('Base/WIP_ASIS_B50.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')


data_50_lt = pd.read_excel('Base/WIP_ASIS_B50_lt.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_run = pd.read_excel('Base/WIP_ASIS_run.xlsx', sheet_name='Sheet1')
data_run2 = pd.read_excel('Base/WIP_ASIS_run2.xlsx', sheet_name='Sheet1')
data_run3 = pd.read_excel('Base/WIP_ASIS_run3.xlsx', sheet_name='Sheet1')

# %%
data = data.iloc[::2]
data_c1 = data_c1.iloc[::2]
data_c2 = data_c2.iloc[::2]
data_c3 = data_c3.iloc[::2]

data_lt = data_lt.iloc[::2]

data_500 = data_500.iloc[::2]
data_500_lt = data_500_lt.iloc[::2]

data_50 = data_50.iloc[::2]
data_50_lt = data_50_lt.iloc[::2]

data_run = data_run.iloc[::2]
data_run2 = data_run2.iloc[::2]
data_run3 = data_run3.iloc[::2]

# %%
print(data.head(10))
print(data_c1.head(10))
# Out:
#     Time  WIP_A  WIP_B  WIP_C  WIP_D  WIP_E  WIP_F  WIP_G  WIP_H  WIP
# 0      0      1      0      0      0      2      0      0      0    3
# 2      5      2      2      0      2      3      2      2      0   13
# 4     10      3      2      0      2      4      2      2      0   15
# 6     15      3      2      0      2      4      2      2      0   15
# 8     20      3      2      0      4      4      3      2      1   19
# 10    25      5      2      0      4      4      4      2      2   23
# 12    30      5      2      0      4      4      4      2      2   23
# 14    35      5      3      0      6      4      4      2      2   26
# 16    40      5      3      0      5      4      6      3      2   28
# 18    45      7      4      0      6      4      6      2      2   31
#     Time  WIP_A  WIP_B  WIP_C  WIP_D  WIP_E  WIP_F  WIP_G  WIP_H  WIP
# 0      0      1      0      0      0      2      0      0      0    3
# ...

# %%
ax = plt.gca()

data.plot(kind='line',x='Time',y='WIP',ax=ax, figsize=(15, 9))
data.plot(kind='line',x='Time',y='WIP_A', color='red', ax=ax)
data.plot(kind='line',x='Time',y='WIP_B', color='green', ax=ax)
data.plot(kind='line',x='Time',y='WIP_C', color='cyan', ax=ax)
data.plot(kind='line',x='Time',y='WIP_D', color='magenta', ax=ax)
data.plot(kind='line',x='Time',y='WIP_E', color='yellow', ax=ax)
data.plot(kind='line',x='Time',y='WIP_F', color='black', ax=ax)
data.plot(kind='line',x='Time',y='WIP_G', color='orange', ax=ax)
data.plot(kind='line',x='Time',y='WIP_H', color='purple', ax=ax)
plt.title('WIP levels (Buffers = 1000)')
plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# Text(0, 0.5, 'Units')

# %%
ax = plt.gca()

data.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=1000')
data_500.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=500')
data_50.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP B=50')


#data_c1.plot(kind='line',x='Time',y='WIP', ax=ax, figsize=(15, 9), label='WIP Scenario 1')
#data_c2.plot(kind='line',x='Time',y='WIP',  ax=ax, label='WIP Scenario 2')
#data_c3.plot(kind='line',x='Time',y='WIP',  ax=ax, label='WIP Scenario 3')

# %%
plt.style.use('seaborn-darkgrid')
ax = plt.gca()

data_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=1000')
data_500_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=500')
data_50_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP B=50')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.title("Evolution of WIP with different buffer capacities", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Time")
plt.ylabel("WIP")

plt.savefig('wip_hypo.png', dpi=400)

# %%
data_c1.mean()
# Out:
# Time     5040.000000
# WIP_A       3.146257
# WIP_B       0.000000
# WIP_C       0.243431
# WIP_D       2.293009
# WIP_E       2.623203
# WIP_F       0.000000
# WIP_G       2.157164
# WIP_H       0.473475
# WIP        10.936539
# dtype: float64

# %%
data_c2.mean()
# Out:
# Time     5040.000000
# WIP_A       2.128904
# WIP_B       2.029251
# WIP_C       0.049579
# WIP_D       0.000000
# WIP_E       0.000000
# WIP_F       2.042142
# WIP_G       0.000000
# WIP_H       0.151710
# WIP         6.401587
# dtype: float64

# %%
data_c3.mean()
# Out:
# Time     5040.000000
# WIP_A       0.000000
# WIP_B       4.029251
# WIP_C       1.049579
# WIP_D       1.088250
# WIP_E       0.000000
# WIP_F       0.148736
# WIP_G       0.000000
# WIP_H       0.151710
# WIP         6.467526
# dtype: float64

# %%
data.mean()
# Out:
# Time     5040.000000
# WIP_A     507.291026
# WIP_B     375.064452
# WIP_C       0.243431
# WIP_D     506.770451
# WIP_E     240.851760
# WIP_F     506.118989
# WIP_G      14.044125
# WIP_H     204.042638
# WIP      2354.426872
# dtype: float64

# %%
data_500.mean()
# Out:
# Time     4713.810429
# WIP_A     457.797936
# WIP_B     343.651820
# WIP_C       0.245519
# WIP_D     457.044541
# WIP_E     237.758827
# WIP_F     456.187941
# WIP_G       8.733840
# WIP_H     191.381858
# WIP      2152.802281
# dtype: float64

# %%
data['WIP'].mean()
# Out:
# 2354.4268715914723

# %%
data_500['WIP'].mean()
# Out:
# 2152.8022813688212

# %%
data_50['WIP'].mean()
# Out:
# 461.5501130369254

# %%
import seaborn as sns
plt.style.use('seaborn-darkgrid')
sns.set_context('talk')
ax = plt.gca()


data_run.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP B=1000',figsize=(15, 9))
#data_run2.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP run #2')
#data_run3.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP run #3')
#data_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=1000')
data_500_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label='WIP B=500')
data_50_lt.plot(kind='line',x='Time',y='WIP',ax=ax, label = 'WIP B=50')




ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.title("Evolution of WIP", loc='left', fontsize=20, fontweight=0, color='black')
plt.xlabel("Time")
plt.ylabel("WIP")

plt.savefig('wip_runin.png', dpi=400)
