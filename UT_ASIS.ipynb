# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import palettable
import numpy as np

# %%
data = pd.read_excel('Base/UT_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c1 = pd.read_excel('SC1/UT_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c2 = pd.read_excel('SC2/UT_ASIS_B1000.xlsx', sheet_name='Sheet1')
data_c3 = pd.read_excel('SC3/UT_ASIS_B1000.xlsx', sheet_name='Sheet1')

data_lt = pd.read_excel('Base/UT_ASIS_B1000_lt.xlsx', sheet_name='Sheet1')

data_500 = pd.read_excel('Base/UT_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_500_lt = pd.read_excel('Base/UT_ASIS_B500_lt.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

data_50 = pd.read_excel('Base/UT_ASIS_B50.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')


data_50_lt = pd.read_excel('Base/UT_ASIS_B50_lt.xlsx', sheet_name='Sheet1')
#data_c1_500 = pd.read_excel('SC1/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c2_500 = pd.read_excel('SC2/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')
#data_c3_500 = pd.read_excel('SC3/WIP_ASIS_B500.xlsx', sheet_name='Sheet1')

# %%
data = data.iloc[::2]
data_c1 = data_c1.iloc[::2]
data_c2 = data_c2.iloc[::2]
data_c3 = data_c3.iloc[::2]

data_lt = data_lt.iloc[::2]

data_500 = data_500.iloc[::2]
data_500_lt = data_500_lt.iloc[::2]

data_50 = data_50.iloc[::2]
data_50_lt = data_50_lt.iloc[::2]

# %%
print(data.head(5))
print(data_c1.head(5))
# Out:
#    Time    M1         M2    M3         M4    M5         M6    M7    M8  \
# 0     0   0.0   0.000000   0.0   0.000000   0.0   0.000000   0.0   0.0
# 2     5  72.0  80.000000  80.0  84.000000  80.0  74.000000  80.0  32.0
# 4    10  72.0  79.500000  80.0  88.000000  80.0  76.000000  80.0  42.5
# 6    15  72.0  63.333333  80.0  85.333333  80.0  77.333333  80.0  48.0
# 8    20  72.0  66.000000  80.0  87.250000  80.0  78.000000  80.0  47.5
#
#           M9        M10        M11        M12
# 0   0.000000   0.000000   0.000000   0.000000
# 2  54.000000  22.000000  74.000000  48.000000
# 4  66.000000  32.000000  76.000000  65.000000
# 6  70.666667  42.666667  77.333333  72.666667
# 8  73.000000  42.000000  78.000000  76.750000
#    Time    M1         M2    M3    M4    M5         M6  M7    M8         M9  \
# 0     0   0.0   0.000000   0.0   0.0   0.0   0.000000   0   0.0   0.000000
# 2     5  48.0  80.000000  80.0  81.0  40.0  74.000000  40  32.0  54.000000
# 4    10  48.0  79.500000  80.0  82.0  40.0  76.000000  40  37.0  66.000000
# 6    15  48.0  79.666667  80.0  84.0  40.0  77.333333  40  40.0  70.666667
# 8    20  48.0  79.750000  80.0  85.0  40.0  78.000000  40  42.0  73.000000
#
#          M10   M11        M12
# 0   0.000000   0.0   0.000000
# 2  34.000000  40.0  48.000000
# 4  41.000000  40.0  59.500000
# 6  47.666667  40.0  63.666667
# 8  51.750000  40.0  65.750000

# %%
from palettable.colorbrewer.qualitative import Dark2_7

ax = plt.gca()


data.plot(kind='line',x='Time',y='M1',ax=ax,figsize=(15, 9),cmap= 'Accent')
data.plot(kind='line',x='Time',y='M2', ax=ax)
data.plot(kind='line',x='Time',y='M3',  ax=ax)
data.plot(kind='line',x='Time',y='M4', ax=ax)
data.plot(kind='line',x='Time',y='M5', ax=ax)
data.plot(kind='line',x='Time',y='M6',  ax=ax)
data.plot(kind='line',x='Time',y='M7',  ax=ax)
data.plot(kind='line',x='Time',y='M8',  ax=ax)
data.plot(kind='line',x='Time',y='M9',  ax=ax)
data.plot(kind='line',x='Time',y='M10',  ax=ax)
data.plot(kind='line',x='Time',y='M11',  ax=ax)
data.plot(kind='line',x='Time',y='M12',  ax=ax)
plt.title('Machine utilization (Buffers = 1000)')
plt.xlabel('Time')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
data.mean()
# Out:
# Time    5040.000000
# M1        66.706126
# M2        60.121677
# M3        79.958310
# M4        89.609066
# M5        79.068887
# M6        79.914490
# M7        76.243219
# M8        53.571066
# M9        79.826575
# M10       47.595916
# M11       76.190963
# M12       85.942830
# dtype: float64

# %%
data_sliced = data.drop('Time', 1)

# %%
data_sliced.mean().plot.bar(rot=0, figsize=(15,6))
plt.title('Machine Utilization for Base (Buffers = 1000)')
plt.xlabel('Machine')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
from palettable.colorbrewer.qualitative import Dark2_7

ax = plt.gca()


data_c1.plot(kind='line',x='Time',y='M1',ax=ax,figsize=(15, 9),cmap= 'Accent')
data_c1.plot(kind='line',x='Time',y='M2', ax=ax)
data_c1.plot(kind='line',x='Time',y='M3',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M4', ax=ax)
data_c1.plot(kind='line',x='Time',y='M5', ax=ax)
data_c1.plot(kind='line',x='Time',y='M6',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M7',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M8',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M9',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M10',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M11',  ax=ax)
data_c1.plot(kind='line',x='Time',y='M12',  ax=ax)
plt.title('Machine utilization for Scenario 1 (Buffers = 1000)')
plt.xlabel('Time')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
data_c1.mean()
data_c1_sliced = data_c1.drop('Time', 1)

data_c1_sliced.mean().plot.bar(rot=0, figsize=(15,6))
plt.title('Machine Utilization for Scenario 1 (Buffers = 1000)')
plt.xlabel('Machine')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
from palettable.colorbrewer.qualitative import Dark2_7

ax = plt.gca()


data_c2.plot(kind='line',x='Time',y='M1',ax=ax,figsize=(15, 9),cmap= 'Accent')
data_c2.plot(kind='line',x='Time',y='M2', ax=ax)
data_c2.plot(kind='line',x='Time',y='M3',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M4', ax=ax)
data_c2.plot(kind='line',x='Time',y='M5', ax=ax)
data_c2.plot(kind='line',x='Time',y='M6',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M7',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M8',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M9',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M10',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M11',  ax=ax)
data_c2.plot(kind='line',x='Time',y='M12',  ax=ax)
plt.title('Machine utilization for Scenario 2 (Buffers = 1000)')
plt.xlabel('Time')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
data_c2.mean()
data_c2_sliced = data_c2.drop('Time', 1)

data_c2_sliced.mean().plot.bar(rot=0, figsize=(15,6))
plt.title('Machine Utilization for Scenario 2 (Buffers = 1000)')
plt.xlabel('Machine')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
from palettable.colorbrewer.qualitative import Dark2_7

ax = plt.gca()


data_c3.plot(kind='line',x='Time',y='M1',ax=ax,figsize=(15, 9),cmap= 'Accent')
data_c3.plot(kind='line',x='Time',y='M2', ax=ax)
data_c3.plot(kind='line',x='Time',y='M3',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M4', ax=ax)
data_c3.plot(kind='line',x='Time',y='M5', ax=ax)
data_c3.plot(kind='line',x='Time',y='M6',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M7',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M8',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M9',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M10',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M11',  ax=ax)
data_c3.plot(kind='line',x='Time',y='M12',  ax=ax)
plt.title('Machine utilization for Scenario 3 (Buffers = 1000)')
plt.xlabel('Time')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
data_c3.mean()
data_c3_sliced = data_c3.drop('Time', 1)

data_c3_sliced.mean().plot.bar(rot=0, figsize=(15,6))
plt.title('Machine Utilization for Scenario 2 (Buffers = 1000)')
plt.xlabel('Machine')
plt.ylabel('% Utilization')
# Out:
# Text(0, 0.5, '% Utilization')

# %%
import seaborn as sns
sns.set_context('talk')

fig, ax = plt.subplots(figsize=(25, 8))

x = np.arange(len(data_c2_sliced.columns))

bar_width = 0.2

b0 = ax.bar(x, data_sliced.mean(), width=bar_width,color="#f9ed69",label ='Base')
b1 = ax.bar(x + bar_width, data_c1_sliced.mean(),width=bar_width,color="#f08a5d", label='Scenario 1')
b2 = ax.bar(x + 2*bar_width, data_c2_sliced.mean(), width=bar_width,color="#b83b5e",label='Scenario 2')
b3 = ax.bar(x + 3*bar_width, data_c3_sliced.mean(), width=bar_width,color="#6a2c70",label='Scenario 3')



# Fix the x-axes.
ax.set_xticks(x + 1.5*bar_width)
ax.set_xticklabels(data_c2_sliced.columns)

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels.
ax.set_xlabel('Machines', labelpad=15)
ax.set_ylabel('% Utilisation', labelpad=15)
ax.set_title('Utilisation in different scenarios', pad=15)

ax.legend()

fig.tight_layout()
#plt.savefig('UT_ASIS.png', dpi=1200)

# %%
data_c1_sliced.mean().mean()
# Out:
# 63.23992256575881

# %%
data_c2_sliced.mean().mean()
# Out:
# 50.61891364008326

# %%
data_c3_sliced.mean().mean()
# Out:
# 47.959945705553395

# %%
data_sliced.mean().mean()
# Out:
# 72.89576033192179

# %%
data_df = data_sliced.mean().to_frame()

# %%
data_sliced.mean().iloc[0:3].mean()
# Out:
# 68.9287043419756

# %%
areas = {'Areas':['A1', 'A2', 'A3', 'A4'], 'UT':[data_sliced.mean().iloc[0:3].mean(), data_sliced.mean().iloc[3:6].mean(), data_sliced.mean().iloc[6:9].mean(), data_sliced.mean().iloc[9:12].mean()]}
areas_df = pd.DataFrame(areas)
areas_base = pd.Series(areas_df['UT'], index=areas_df.index)

# %%
areas_c1 = {'Areas':['A1', 'A2', 'A3', 'A4'], 'UT':[data_c1_sliced.mean().iloc[0:3].mean(), data_c1_sliced.mean().iloc[3:6].mean(), data_c1_sliced.mean().iloc[6:9].mean(), data_c1_sliced.mean().iloc[9:12].mean()]}
areas_df_c1 = pd.DataFrame(areas_c1)
areas_c1 = pd.Series(areas_df_c1['UT'], index=areas_df_c1.index)

# %%
areas_c2 = {'Areas':['A1', 'A2', 'A3', 'A4'], 'UT':[data_c2_sliced.mean().iloc[0:3].mean(), data_c2_sliced.mean().iloc[3:6].mean(), data_c2_sliced.mean().iloc[6:9].mean(), data_c2_sliced.mean().iloc[9:12].mean()]}
areas_df_c2 = pd.DataFrame(areas_c2)
areas_c2 = pd.Series(areas_df_c2['UT'], index=areas_df_c2.index)

# %%
areas_c3 = {'Areas':['A1', 'A2', 'A3', 'A4'], 'UT':[data_c3_sliced.mean().iloc[0:3].mean(), data_c3_sliced.mean().iloc[3:6].mean(), data_c3_sliced.mean().iloc[6:9].mean(), data_c3_sliced.mean().iloc[9:12].mean()]}
areas_df_c3 = pd.DataFrame(areas_c3)
areas_c3 = pd.Series(areas_df_c3['UT'], index=areas_df_c3.index)

# %%
import seaborn as sns
sns.set_context('poster')

fig, ax = plt.subplots(figsize=(25, 8))

x = np.arange(4)

bar_width = 0.2

b0 = ax.bar(x, areas_base, width=bar_width,color="#f9ed69",label ='Base')
b1 = ax.bar(x + bar_width, areas_c1,width=bar_width,color="#f08a5d", label='Scenario 1')
b2 = ax.bar(x + 2*bar_width, areas_c2, width=bar_width,color="#b83b5e",label='Scenario 2')
b3 = ax.bar(x + 3*bar_width, areas_c3, width=bar_width,color="#6a2c70",label='Scenario 3')



# Fix the x-axes.
ax.set_xticks(x + 1.5*bar_width)
ax.set_xticklabels(('Area 1','Area 2','Area 3','Area 4'))

# Axis styling.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels.
#ax.set_xlabel('Functional areas', labelpad=15)
ax.set_ylabel('% Utilisation', labelpad=15)
ax.set_title('Utilisation of functional areas', pad=15)


ax.legend()

plt.legend(bbox_to_anchor=(0.95,0.6,0.15,0.2), loc="lower right", mode="expand", borderaxespad=0, ncol=1)



fig.tight_layout()
plt.savefig('UT_AREAS_ASIS.png', transparent=True, dpi=200)

# %%
areas_base
# Out:
# 0    68.928704
# 1    82.864148
# 2    69.880286
# 3    69.909903
# Name: UT, dtype: float64

# %%
areas_base.std()
# Out:
# 6.661198813380475

# %%
areas_c1.std()
# Out:
# 7.04947879754263

# %%
areas_c2.std()
# Out:
# 6.506543337956961

# %%
areas_c3.std()
# Out:
# 6.518116831338458

# %%
(areas_base.std()+areas_c1.std()+areas_c2.std()+areas_c3.std())/4
# Out:
# 6.6838344450546305

# %%
data_c3_sliced.mean()
# Out:
# M1     47.976131
# M2     39.980048
# M3     39.980169
# M4     47.972459
# M5     39.980169
# M6     39.979245
# M7     79.958309
# M8     47.953202
# M9     39.977955
# M10    23.936896
# M11    79.913993
# M12    47.910773
# dtype: float64

# %%
TH_df = pd.DataFrame({'x':data['Time'],'Total UT': data[M1]+data[M2]+data[M3]+})
# Out:
#   File "<ipython-input-34-9047701c183f>", line 1
#     TH_df = pd.DataFrame({'x':data['Time'],'Total UT': data[M1]+data[M2]+data[M3]+})
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
copy_data_df = data.copy()
del copy_data_df['Time']
data['UT_mean'] = copy_data_df.mean(numeric_only=True, axis=1)
data = data[:100] #keep top 3000
data

# %%
 #plt.style.use('fivethirtyeight')
plt.style.use('seaborn-darkgrid')
my_dpi=96
plt.figure(figsize=(480/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# multiple line plot
for column in data.drop('Time', axis=1):
   plt.plot(data['Time'], data[column], marker='', color='grey', linewidth=1, alpha=0.4)
 
# Now re do the interesting curve, but biger with distinct color
plt.plot(data['Time'], data['UT_mean'], marker='', color='orange', linewidth=4, alpha=0.7)
 
# Change xlim
plt.xlim(0,500)
plt.ylim(ymin = 0.25)
 
# Let's annotate the plot
num=0
for i in data.values[14][1:]:
   num+=1
   name=list(data)[num]
   if name != 'UT_mean':
      plt.text(520, i, name, horizontalalignment='right', size='small', color='grey')
 
# And add a special annotation for the group we are interested in
plt.text(520, data.UT_mean.tail(1), 'UT_mean', horizontalalignment='left', size='small', color='orange')
 
# Add titles
plt.title("Evolution of utilisation Base as-is", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Time")
plt.ylabel("TH")

#plt.savefig('_time.png', dpi=400)

# %%
data_sliced.mean().mean()

# %%
data_500_sliced = data_500.drop('Time',1)

# %%
data_500_sliced.mean().mean()

# %%
data_50_sliced = data_50.drop('Time',1)

# %%
data_50_sliced.mean().mean()
